# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain.agents import create_agent
from langgraph.checkpoint.memory import InMemorySaver

agent = create_agent(
    model = "deepseek-chat",
    checkpointer=InMemorySaver()
)

# %%
from langgraph.types import Checkpointer
import sqlite3
from langgraph.checkpoint.sqlite import SqliteSaver

connection = sqlite3.connect("resources/checkpint.db",check_same_thread=False)
checkpointer = SqliteSaver(connection)

checkpointer.setup()

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage

agent = create_agent(
    model = "deepseek-chat",
    checkpointer=checkpointer
)

config = {
    "configurable":{
        "thread_id":"thread_1"
    }
}

response = agent.invoke(
    {"messages":[HumanMessage("你好, 我叫meok, 我喜欢猫")]},
    config = config
)
print(response)
# Out:
# {'messages': [HumanMessage(content='你好, 我叫meok, 我喜欢猫', additional_kwargs={}, response_metadata={}, id='6d7b084d-05f9-42b1-a21c-c418375c4e90'), AIMessage(content='你好，Meok！很高兴认识你！🐱  \n我也很喜欢猫呢——它们毛茸茸的样子、优雅的步伐，还有那些让人猜不透的小心思，都特别迷人。  \n你最喜欢猫的哪种特质呀？是它们独立又黏人的反差，还是那双会说话的眼睛？  \n（或者……你家有猫主子吗？想听你分享它们的故事！）😺', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 81, 'prompt_tokens': 14, 'total_tokens': 95, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cache_write_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 14}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'a26a7955944dc5c60445bff77fac9c8e', 'id': '33bf3aa2-27d7-4299-a1cc-0471d34ffec8', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a000c1-21bc-7160-a58d-2a71523b91e4-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 14, 'output_tokens': 81, 'total_tokens': 95, 'input_token_details': {'cache_read': 0}, 'output_token_details': {}})]}

# %%
response = agent.invoke(
    {"messages":[HumanMessage("我喜欢什么动物")]},
    config = config
)
print(response)
# Out:
# {'messages': [HumanMessage(content='你好, 我叫meok, 我喜欢猫', additional_kwargs={}, response_metadata={}, id='6d7b084d-05f9-42b1-a21c-c418375c4e90'), AIMessage(content='你好，Meok！很高兴认识你！🐱  \n我也很喜欢猫呢——它们毛茸茸的样子、优雅的步伐，还有那些让人猜不透的小心思，都特别迷人。  \n你最喜欢猫的哪种特质呀？是它们独立又黏人的反差，还是那双会说话的眼睛？  \n（或者……你家有猫主子吗？想听你分享它们的故事！）😺', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 81, 'prompt_tokens': 14, 'total_tokens': 95, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cache_write_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 14}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'a26a7955944dc5c60445bff77fac9c8e', 'id': '33bf3aa2-27d7-4299-a1cc-0471d34ffec8', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a000c1-21bc-7160-a58d-2a71523b91e4-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 14, 'output_tokens': 81, 'total_tokens': 95, 'input_token_details': {'cache_read': 0}, 'output_token_details': {}}), HumanMessage(content='我喜欢什么动物', additional_kwargs={}, response_metadata={}, id='98fac27a-0fdd-442a-9f43-db2a3a6694f2'), AIMessage(content='哈哈，你上次说喜欢猫，这次问“我喜欢什么动物”——如果按照已知信息推理，那答案大概率是 **猫**！不过既然你特意再问，我猜可能有这些情况：\n\n1. **你想确认我是否记得之前的对话** → 那我认真回答：你提过喜欢猫，所以我猜你喜欢猫 🐾  \n2. **你想探索新答案** → 那我要反问啦：你会喜欢*猫以外的动物*吗？比如狗（热情派）、兔子（软萌派）、还是冷门但酷的（比如水獭或蜜袋鼯）？  \n3. **你在和我玩“猜谜游戏”** → 那我盲猜一个：**猫 + 所有毛茸茸的动物**！✨  \n\n悄悄说，如果你告诉我一种动物，我就能给你讲它的冷知识或者超可爱小故事哦～（比如猫的呼噜声有治愈频率！）😉  \n所以……你想让我猜，还是直接告诉我答案呀？', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 210, 'prompt_tokens': 102, 'total_tokens': 312, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cache_write_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 102}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'a26a7955944dc5c60445bff77fac9c8e', 'id': '0971c521-daa8-41b0-b3b5-896ef632d4d1', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a000c1-2882-7812-970d-2f082b6944d1-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 102, 'output_tokens': 210, 'total_tokens': 312, 'input_token_details': {'cache_read': 0}, 'output_token_details': {}})]}
