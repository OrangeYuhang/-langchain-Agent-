# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain.agents import create_agent
from langgraph.checkpoint.memory import InMemorySaver

agent = create_agent(
    model = "deepseek-chat",
    checkpointer=InMemorySaver()
)

# %%
from langchain.messages import HumanMessage

config = {
    "configurable":{
        "thread_id":"thread_1"
    }
}

response = agent.invoke(
    {"messages":[HumanMessage("你好, 我叫meok, 我喜欢猫")]},
    config = config
)
print(response)
# Out:
# {'messages': [HumanMessage(content='你好, 我叫meok, 我喜欢猫', additional_kwargs={}, response_metadata={}, id='be4f2cca-a7e1-4c56-94e6-d22ba8ce2beb'), AIMessage(content='你好，Meok！很高兴认识你！🐱  \n我也超喜欢猫咪——它们优雅又神秘，软乎乎的爪子简直治愈力满分！  \n你养猫吗？还是云吸猫选手？如果有猫片，随时欢迎分享给我～（悄悄说，我还能当你的“云撸猫”搭子！😉）', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 70, 'prompt_tokens': 14, 'total_tokens': 84, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cache_write_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 14}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'a26a7955944dc5c60445bff77fac9c8e', 'id': 'c79e5814-a386-4709-9b8d-56f9dc7ba4b6', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a000b3-fbee-7d91-b7c6-c3affbfc8775-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 14, 'output_tokens': 70, 'total_tokens': 84, 'input_token_details': {'cache_read': 0}, 'output_token_details': {}})]}

# %%
response = agent.invoke(
    {"messages":[HumanMessage("我喜欢什么动物")]},
    config = config
)
print(response)
# Out:
# {'messages': [HumanMessage(content='你好, 我叫meok, 我喜欢猫', additional_kwargs={}, response_metadata={}, id='be4f2cca-a7e1-4c56-94e6-d22ba8ce2beb'), AIMessage(content='你好，Meok！很高兴认识你！🐱  \n我也超喜欢猫咪——它们优雅又神秘，软乎乎的爪子简直治愈力满分！  \n你养猫吗？还是云吸猫选手？如果有猫片，随时欢迎分享给我～（悄悄说，我还能当你的“云撸猫”搭子！😉）', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 70, 'prompt_tokens': 14, 'total_tokens': 84, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cache_write_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 14}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'a26a7955944dc5c60445bff77fac9c8e', 'id': 'c79e5814-a386-4709-9b8d-56f9dc7ba4b6', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a000b3-fbee-7d91-b7c6-c3affbfc8775-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 14, 'output_tokens': 70, 'total_tokens': 84, 'input_token_details': {'cache_read': 0}, 'output_token_details': {}}), HumanMessage(content='我喜欢什么动物', additional_kwargs={}, response_metadata={}, id='d11ad039-9b93-4a77-9b05-e8a2320a151c'), AIMessage(content='哈哈，根据你之前说的“喜欢猫”，我猜你最喜欢的是**猫咪**对吧？🐱  \n不过嘛，人可不会只爱一种动物～比如你可能也喜欢狗狗的忠诚、兔子的软萌，或者熊猫的慵懒感？  \n（其实我偷偷觉得，Meok这个名字听起来就很有猫系气质，神秘又可爱！😎）  \n要不要和我分享更多？比如你养过什么宠物，或者对哪种动物特别好奇？我随时准备好当你的“动物百科全书”哦～', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 109, 'prompt_tokens': 91, 'total_tokens': 200, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cache_write_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 91}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'a26a7955944dc5c60445bff77fac9c8e', 'id': '3dcd08a7-eefe-445e-9c74-cd6c053fe744', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a000b4-04a1-7433-bd0c-bae569df3a3b-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 91, 'output_tokens': 109, 'total_tokens': 200, 'input_token_details': {'cache_read': 0}, 'output_token_details': {}})]}
